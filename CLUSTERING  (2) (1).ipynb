# %% [markdown]
# # Understanding and Implementing K-Means, Hierarchical, and DBSCAN Algorithms

# %% [markdown]
# ## Data Preprocessing:

# %% [markdown]
# ##### 1. Preprocess the dataset to handle missing values, remove outliers, and scale the features if necessary.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\datascience2025\assignments\EastWestAirlines.csv")

# %%
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.info
# Out:
# <bound method DataFrame.info of        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
df.isnull().sum()  ## Check for missing values
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.iloc[:, 1:])
scaled_data
# Out:
# array([[0.01650773, 0.        , 0.        , ..., 0.        , 0.84374246,
#         0.        ],
#        [0.01128788, 0.        , 0.        , ..., 0.        , 0.83988425,
#         0.        ],
#        [0.02425685, 0.        , 0.        , ..., 0.        , 0.84784181,
#         0.        ],
#        ...,
#        [0.0431695 , 0.        , 0.5       , ..., 0.        , 0.16879672,
#         1.        ],
#        [0.03220189, 0.        , 0.        , ..., 0.01886792, 0.16867615,
#         0.        ],
#        [0.00176908, 0.        , 0.        , ..., 0.        , 0.16831444,
#         0.        ]])

# %%
model = AgglomerativeClustering (n_clusters=3, metric='euclidean', linkage='complete')
model.fit(scaled_data)
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=3)

# %%
model.labels_
# Out:
# array([2, 2, 2, ..., 0, 2, 2], dtype=int64)

# %%
df['Cluster'] = model.labels_
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.iloc[:, 1:].groupby(df.Cluster).mean()
# Out:
#                Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Cluster
# 0         97189.586113  239.728387   2.670524   1.007488   1.014295
# 1        131999.500000  347.000000   2.500000   1.000000   1.000000
# 2         59791.056611   88.188836   1.703484   1.018606   1.011085
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# Cluster
# 0        28739.993193    15.588836         801.789653         2.449285
# 1        65634.250000    69.250000       19960.000000        49.250000
# 2        10324.882423     9.192003         230.441013         0.672209
#
#          Days_since_enroll    Award?  Cluster
# Cluster
# 0              4628.761743  1.000000      0.0
# 1              2200.250000  1.000000      1.0
# 2              3824.887965  0.003167      2.0

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
linked = linkage(scaled_data, 'complete')
dn = dendrogram(linked, color_threshold=1.0)

# %% [markdown]
# # K mean

# %%
scaler = StandardScaler()
data_scaled = pd.DataFrame(scaler.fit_transform(df.iloc[:,1:]))
data_scaled
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786 -1.104065
# 1    -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088 -0.999926
# 2    -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253 -0.791649
# 3    -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 4     0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121  1.499394
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960 -0.791649
# 3995 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367 -0.687511
# 3996 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804 -0.375096
# 3997 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 3998 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992 -1.208203
#
#             7         8         9         10        11
# ...

# %%
model = KMeans(n_clusters = 3)
cluster=model.fit(data_scaled)

# %%
len(cluster.labels_)
# Out:
# 3999

# %%
df.shape
# Out:
# (3999, 13)

# %%
data_scaled['labels']=cluster.labels_
data_scaled
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786 -1.104065
# 1    -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088 -0.999926
# 2    -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253 -0.791649
# 3    -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 4     0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121  1.499394
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960 -0.791649
# 3995 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367 -0.687511
# 3996 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804 -0.375096
# 3997 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 3998 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992 -1.208203
#
#              7         8         9        10        11  labels
# ...

# %%
data_scaled.groupby('labels').mean()
# Out:
#                0         1         2         3         4         5         6  \
# labels
# 0       1.572491  0.777051  0.369470  0.132677  0.082760  1.090286  1.819502
# 1      -0.168599 -0.075740 -0.285836  0.019823 -0.044079 -0.321227 -0.293288
# 2       0.102637  0.036939  0.472073 -0.053284  0.069452  0.442903  0.297426
#
#                7         8         9        10        11
# labels
# 0       3.242552  3.616770  0.382343  0.962701 -0.910817
# 1      -0.201544 -0.227717 -0.152709 -0.763562  0.763223
# 2      -0.054189 -0.055143  0.228202  1.264212 -1.270330

# %%
model.inertia_
# Out:
# 33070.49255823193

# %%
data_scaled.columns = data_scaled.columns.astype(str)

# %%
wcss =[]
for i in range(1,11):
    model = KMeans(n_clusters=i)
    model.fit(data_scaled)
    wcss.append(model.inertia_)
wcss
# Out:
# [49171.81295323833,
#  38299.47732245199,
#  34471.147181924825,
#  29254.69307473966,
#  27355.892032109467,
#  23661.534483941727,
#  23498.466213638796,
#  18983.869042351886,
#  16451.48686757432,
#  15990.968147658745]

# %% [markdown]
# # visualization

# %%
plt.plot(range(1,11),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import StandardScaler

# Sample data
np.random.seed(42)
X = np.random.rand(200, 2) * 10  # Generate some random points

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# DBSCAN clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_labels = dbscan.fit_predict(X_scaled)

# Agglomerative clustering
agglo = AgglomerativeClustering(n_clusters=3)
agglo_labels = agglo.fit_predict(X_scaled)

# Evaluation Metrics
dbscan_silhouette = silhouette_score(X_scaled, dbscan_labels) if len(set(dbscan_labels)) > 1 else None
dbscan_davies_bouldin = davies_bouldin_score(X_scaled, dbscan_labels) if len(set(dbscan_labels)) > 1 else None

agglo_silhouette = silhouette_score(X_scaled, agglo_labels)
agglo_davies_bouldin = davies_bouldin_score(X_scaled, agglo_labels)

print(f"DBSCAN: Silhouette Score = {dbscan_silhouette}, Davies-Bouldin Score = {dbscan_davies_bouldin}")
print(f"Agglomerative: Silhouette Score = {agglo_silhouette}, Davies-Bouldin Score = {agglo_davies_bouldin}")

# Visualizing results
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=dbscan_labels, cmap='viridis', edgecolors='k')
plt.title("DBSCAN Clustering")

plt.subplot(1, 2, 2)
plt.scatter(X[:, 0], X[:, 1], c=agglo_labels, cmap='plasma', edgecolors='k')
plt.title("Agglomerative Clustering")

plt.show()
# Out:
# DBSCAN: Silhouette Score = None, Davies-Bouldin Score = None
# Agglomerative: Silhouette Score = 0.40814642515723776, Davies-Bouldin Score = 0.8015319577473464
